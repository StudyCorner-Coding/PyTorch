# %% [markdown]
# PyTorch provides the torch.nn module, which simplifies building, training, and optimizing neural networks. Below is a comprehensive guide to using the PyTorch Neural Network API.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
